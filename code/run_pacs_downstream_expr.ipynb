# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !apt-get install libmagickwand-dev
# !pip install wand
# !pip install datasets

# %%
import os
import sys

sys.path.append('/content/drive/MyDrive/clear-vae')
os.chdir('/content/drive/MyDrive/clear-vae')

# %%
from datasets import load_dataset

# %%
ds = load_dataset("flwrlabs/pacs")
ds.save_to_disk("/content/pacs")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/3.89k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/191M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9991 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/9991 [00:00<?, ? examples/s]

# %%
for i in range(10):
    print(f"Running iteration {i+1}")
    # !python run_pacs_downstream_expr.py --data_root_path /content/ --temperature 0.1
    print(f"Complete iteration {i+1}")

from tqdm import tqdm
import time

for i in tqdm(range(5)):
    time.sleep(1)

# !kill $(ps aux | awk '{print $2}')
# Out:
# Streaming output truncated to the last 5000 lines.
# val_recontr_loss=1494.803, val_kl_c=15.895, val_kl_s=28.961, val_c_loss=0.830, val_s_loss=0.177
# gMIG: -0.021; mse: 1494.803
# Epoch 15: 100% 17/17 [00:01<00:00, 16.88batch/s, c_loss=0.31, kl_c=13.7, kl_s=29.4, recontr_loss=1.52e+3, s_loss=0.192]
# val-epoch 15: 100% 3/3 [00:00<00:00,  8.06it/s]
# val_recontr_loss=1378.615, val_kl_c=13.299, val_kl_s=29.007, val_c_loss=0.823, val_s_loss=0.185
# gMIG: -0.032; mse: 1378.615
# Epoch 20: 100% 17/17 [00:00<00:00, 17.79batch/s, c_loss=0.0715, kl_c=14.7, kl_s=33, recontr_loss=1.53e+3, s_loss=0.236]
# val-epoch 20: 100% 3/3 [00:00<00:00,  7.90it/s]
# val_recontr_loss=1318.210, val_kl_c=15.185, val_kl_s=38.477, val_c_loss=0.816, val_s_loss=0.191
# gMIG: -0.055; mse: 1318.21
# Epoch 25: 100% 17/17 [00:00<00:00, 17.77batch/s, c_loss=0.133, kl_c=20.9, kl_s=47, recontr_loss=1.41e+3, s_loss=0.245]
# val-epoch 25: 100% 3/3 [00:00<00:00,  7.90it/s]
# val_recontr_loss=1249.018, val_kl_c=21.312, val_kl_s=52.355, val_c_loss=0.825, val_s_loss=0.190
# gMIG: -0.084; mse: 1249.018
# Epoch 30: 100% 17/17 [00:00<00:00, 17.45batch/s, c_loss=0.0793, kl_c=28.8, kl_s=61.1, recontr_loss=1.13e+3, s_loss=0.172]
# val-epoch 30: 100% 3/3 [00:00<00:00,  7.80it/s]
# val_recontr_loss=1239.036, val_kl_c=27.704, val_kl_s=61.394, val_c_loss=0.827, val_s_loss=0.192
# gMIG: -0.087; mse: 1239.036
# Epoch 35: 100% 17/17 [00:01<00:00, 16.82batch/s, c_loss=0.0377, kl_c=33.7, kl_s=71.6, recontr_loss=1.11e+3, s_loss=0.221]
# val-epoch 35: 100% 3/3 [00:00<00:00,  7.91it/s]
# val_recontr_loss=1248.605, val_kl_c=34.076, val_kl_s=68.847, val_c_loss=0.798, val_s_loss=0.189
# gMIG: -0.085; mse: 1248.605
# Epoch 40: 100% 17/17 [00:00<00:00, 17.40batch/s, c_loss=0.219, kl_c=40.6, kl_s=73.1, recontr_loss=1.27e+3, s_loss=0.172]
# val-epoch 40: 100% 3/3 [00:00<00:00,  8.02it/s]
# val_recontr_loss=1229.931, val_kl_c=40.209, val_kl_s=75.787, val_c_loss=0.782, val_s_loss=0.191
# gMIG: -0.081; mse: 1229.931
# epoch 0: 100% 17/17 [00:00<00:00, 19.01batch/s, loss=1.58]
# val-epoch 0: 100% 3/3 [00:00<00:00,  8.04it/s]
# val_aupr: {0: np.float64(0.473), 1: np.float64(0.771), 2: np.float64(0.553), 3: np.float64(0.689), 4: np.float64(0.408), 5: np.float64(0.712), 6: np.float64(0.387)}
# 0.57
# val_auroc: {0: np.float64(0.819), 1: np.float64(0.929), 2: np.float64(0.865), 3: np.float64(0.956), 4: np.float64(0.862), 5: np.float64(0.934), 6: np.float64(0.722)}
# 0.87
# val_acc: 0.639
# epoch 10: 100% 17/17 [00:00<00:00, 18.83batch/s, loss=0.123]
# val-epoch 10: 100% 3/3 [00:00<00:00,  8.30it/s]
# val_aupr: {0: np.float64(0.664), 1: np.float64(0.992), 2: np.float64(0.695), 3: np.float64(0.894), 4: np.float64(0.486), 5: np.float64(0.78), 6: np.float64(0.613)}
# 0.732
# val_auroc: {0: np.float64(0.915), 1: np.float64(0.997), 2: np.float64(0.924), 3: np.float64(0.969), 4: np.float64(0.927), 5: np.float64(0.942), 6: np.float64(0.867)}
# 0.934
# val_acc: 0.754
# epoch 20: 100% 17/17 [00:00<00:00, 18.77batch/s, loss=0.0737]
# val-epoch 20: 100% 3/3 [00:00<00:00,  8.02it/s]
# val_aupr: {0: np.float64(0.666), 1: np.float64(0.993), 2: np.float64(0.702), 3: np.float64(0.906), 4: np.float64(0.466), 5: np.float64(0.777), 6: np.float64(0.628)}
# 0.734
# val_auroc: {0: np.float64(0.916), 1: np.float64(0.997), 2: np.float64(0.926), 3: np.float64(0.972), 4: np.float64(0.925), 5: np.float64(0.939), 6: np.float64(0.87)}
# 0.935
# val_acc: 0.757
# epoch 30: 100% 17/17 [00:01<00:00, 16.60batch/s, loss=0.0253]
# val-epoch 30: 100% 3/3 [00:00<00:00,  7.90it/s]
# val_aupr: {0: np.float64(0.667), 1: np.float64(0.994), 2: np.float64(0.701), 3: np.float64(0.908), 4: np.float64(0.453), 5: np.float64(0.77), 6: np.float64(0.631)}
# 0.732
# val_auroc: {0: np.float64(0.917), 1: np.float64(0.997), 2: np.float64(0.925), 3: np.float64(0.973), 4: np.float64(0.921), 5: np.float64(0.937), 6: np.float64(0.871)}
# 0.934
# val_acc: 0.76
# epoch 40: 100% 17/17 [00:00<00:00, 18.67batch/s, loss=0.0273]
# val-epoch 40: 100% 3/3 [00:00<00:00,  8.54it/s]
# val_aupr: {0: np.float64(0.665), 1: np.float64(0.995), 2: np.float64(0.691), 3: np.float64(0.909), 4: np.float64(0.457), 5: np.float64(0.767), 6: np.float64(0.635)}
# 0.731
# val_auroc: {0: np.float64(0.917), 1: np.float64(0.998), 2: np.float64(0.92), 3: np.float64(0.974), 4: np.float64(0.923), 5: np.float64(0.933), 6: np.float64(0.869)}
# 0.933
# val_acc: 0.76
#
# Results:
# {
#   "baseline": {
#     "acc": 0.089,
#     "pr": {
#       "overall": 0.173,
#       "stratified": {
#         "0": 0.135,
#         "1": 0.084,
#         "2": 0.137,
#         "3": 0.275,
#         "4": 0.129,
#         "5": 0.18,
#         "6": 0.274
#       }
#     },
#     "roc": {
#       "overall": 0.508,
#       "stratified": {
#         "0": 0.383,
#         "1": 0.321,
#         "2": 0.41,
#         "3": 0.701,
#         "4": 0.348,
#         "5": 0.694,
#         "6": 0.701
#       }
#     }
#   },
#   "lam0": {
#     "acc": 0.09,
#     "pr": {
#       "overall": 0.19,
#       "stratified": {
#         "0": 0.131,
#         "1": 0.08,
#         "2": 0.131,
#         "3": 0.418,
#         "4": 0.127,
#         "5": 0.211,
#         "6": 0.231
#       }
#     },
#     "roc": {
#       "overall": 0.51,
#       "stratified": {
#         "0": 0.364,
#         "1": 0.289,
#         "2": 0.386,
#         "3": 0.806,
#         "4": 0.325,
#         "5": 0.721,
#         "6": 0.678
#       }
#     }
#   },
#   "lam1": {
#     "acc": 0.1,
#     "pr": {
#       "overall": 0.201,
#       "stratified": {
#         "0": 0.129,
#         "1": 0.079,
#         "2": 0.13,
#         "3": 0.516,
#         "4": 0.126,
#         "5": 0.206,
#         "6": 0.224
#       }
#     },
#     "roc": {
#       "overall": 0.506,
#       "stratified": {
#         "0": 0.348,
#         "1": 0.272,
#         "2": 0.388,
#         "3": 0.812,
#         "4": 0.325,
#         "5": 0.719,
#         "6": 0.679
#       }
#     }
#   },
#   "lam2": {
#     "acc": 0.07,
#     "pr": {
#       "overall": 0.174,
#       "stratified": {
#         "0": 0.131,
#         "1": 0.08,
#         "2": 0.13,
#         "3": 0.353,
#         "4": 0.129,
#         "5": 0.191,
#         "6": 0.203
#       }
#     },
#     "roc": {
#       "overall": 0.502,
#       "stratified": {
#         "0": 0.358,
#         "1": 0.282,
#         "2": 0.377,
#         "3": 0.774,
#         "4": 0.334,
#         "5": 0.717,
#         "6": 0.67
#       }
#     }
#   },
#   "lam3": {
#     "acc": 0.097,
#     "pr": {
#       "overall": 0.193,
#       "stratified": {
#         "0": 0.128,
#         "1": 0.082,
#         "2": 0.128,
#         "3": 0.423,
#         "4": 0.126,
#         "5": 0.187,
#         "6": 0.276
#       }
#     },
#     "roc": {
#       "overall": 0.509,
#       "stratified": {
#         "0": 0.343,
#         "1": 0.304,
#         "2": 0.371,
#         "3": 0.805,
#         "4": 0.317,
#         "5": 0.709,
#         "6": 0.713
#       }
#     }
#   },
#   "clear": {
#     "acc": 0.097,
#     "pr": {
#       "overall": 0.179,
#       "stratified": {
#         "0": 0.139,
#         "1": 0.078,
#         "2": 0.136,
#         "3": 0.419,
#         "4": 0.131,
#         "5": 0.163,
#         "6": 0.19
#       }
#     },
#     "roc": {
#       "overall": 0.486,
#       "stratified": {
#         "0": 0.402,
#         "1": 0.263,
#         "2": 0.422,
#         "3": 0.732,
#         "4": 0.343,
#         "5": 0.639,
#         "6": 0.602
#       }
#     }
#   }
# }
# Experiment: k=2, seed=76
# {0: {'test': ['art_painting', 'cartoon'], 'train': ['sketch', 'photo']},
#  1: {'test': ['cartoon', 'sketch'], 'train': ['photo', 'art_painting']},
#  2: {'test': ['cartoon', 'photo'], 'train': ['sketch', 'art_painting']},
#  3: {'test': ['cartoon', 'sketch'], 'train': ['art_painting', 'photo']},
#  4: {'test': ['art_painting', 'cartoon'], 'train': ['photo', 'sketch']},
#  5: {'test': ['art_painting', 'photo'], 'train': ['cartoon', 'sketch']},
#  6: {'test': ['art_painting', 'photo'], 'train': ['cartoon', 'sketch']}}
#
# Training baseline:
# epoch 0: 100% 32/32 [00:01<00:00, 19.50batch/s, loss=1.46]
# val-epoch 0: 100% 6/6 [00:00<00:00, 11.02it/s]
# val_aupr: {0: np.float64(0.351), 1: np.float64(0.341), 2: np.float64(0.423), 3: np.float64(0.495), 4: np.float64(0.402), 5: np.float64(0.123), 6: np.float64(0.411)}
# 0.364
# val_auroc: {0: np.float64(0.718), 1: np.float64(0.885), 2: np.float64(0.746), 3: np.float64(0.926), 4: np.float64(0.717), 5: np.float64(0.625), 6: np.float64(0.66)}
# 0.754
# val_acc: 0.325
# epoch 5: 100% 32/32 [00:01<00:00, 19.42batch/s, loss=0.123]
# val-epoch 5: 100% 6/6 [00:00<00:00, 10.43it/s]
# val_aupr: {0: np.float64(0.454), 1: np.float64(0.444), 2: np.float64(0.648), 3: np.float64(0.568), 4: np.float64(0.492), 5: np.float64(0.798), 6: np.float64(0.805)}
# 0.601
# val_auroc: {0: np.float64(0.775), 1: np.float64(0.892), 2: np.float64(0.829), 3: np.float64(0.943), 4: np.float64(0.774), 5: np.float64(0.96), 6: np.float64(0.933)}
# 0.872
# val_acc: 0.543
# epoch 10: 100% 32/32 [00:01<00:00, 18.94batch/s, loss=0.0269]
# val-epoch 10: 100% 6/6 [00:00<00:00, 10.88it/s]
# val_aupr: {0: np.float64(0.449), 1: np.float64(0.436), 2: np.float64(0.644), 3: np.float64(0.56), 4: np.float64(0.482), 5: np.float64(0.786), 6: np.float64(0.809)}
# 0.595
# val_auroc: {0: np.float64(0.759), 1: np.float64(0.88), 2: np.float64(0.82), 3: np.float64(0.925), 4: np.float64(0.764), 5: np.float64(0.951), 6: np.float64(0.932)}
# 0.862
# val_acc: 0.556
# epoch 15: 100% 32/32 [00:01<00:00, 19.77batch/s, loss=0.0145]
# val-epoch 15: 100% 6/6 [00:00<00:00, 10.92it/s]
# val_aupr: {0: np.float64(0.443), 1: np.float64(0.444), 2: np.float64(0.641), 3: np.float64(0.548), 4: np.float64(0.475), 5: np.float64(0.782), 6: np.float64(0.806)}
# 0.591
# val_auroc: {0: np.float64(0.749), 1: np.float64(0.881), 2: np.float64(0.816), 3: np.float64(0.918), 4: np.float64(0.757), 5: np.float64(0.952), 6: np.float64(0.93)}
# 0.858
# val_acc: 0.546
# epoch 20: 100% 32/32 [00:01<00:00, 19.20batch/s, loss=0.00757]
# val-epoch 20: 100% 6/6 [00:00<00:00, 11.20it/s]
# val_aupr: {0: np.float64(0.44), 1: np.float64(0.447), 2: np.float64(0.636), 3: np.float64(0.542), 4: np.float64(0.475), 5: np.float64(0.778), 6: np.float64(0.802)}
# 0.589
# val_auroc: {0: np.float64(0.746), 1: np.float64(0.883), 2: np.float64(0.811), 3: np.float64(0.921), 4: np.float64(0.757), 5: np.float64(0.95), 6: np.float64(0.926)}
# 0.856
# val_acc: 0.545
# epoch 25: 100% 32/32 [00:01<00:00, 19.42batch/s, loss=0.0101]
# val-epoch 25: 100% 6/6 [00:00<00:00, 11.05it/s]
# val_aupr: {0: np.float64(0.44), 1: np.float64(0.44), 2: np.float64(0.64), 3: np.float64(0.539), 4: np.float64(0.466), 5: np.float64(0.779), 6: np.float64(0.8)}
# 0.586
# val_auroc: {0: np.float64(0.742), 1: np.float64(0.881), 2: np.float64(0.815), 3: np.float64(0.913), 4: np.float64(0.749), 5: np.float64(0.953), 6: np.float64(0.927)}
# 0.854
# val_acc: 0.539
# epoch 30: 100% 32/32 [00:01<00:00, 19.57batch/s, loss=0.00409]
# val-epoch 30: 100% 6/6 [00:00<00:00, 10.68it/s]
# val_aupr: {0: np.float64(0.438), 1: np.float64(0.442), 2: np.float64(0.636), 3: np.float64(0.534), 4: np.float64(0.468), 5: np.float64(0.777), 6: np.float64(0.805)}
# 0.586
# val_auroc: {0: np.float64(0.739), 1: np.float64(0.879), 2: np.float64(0.811), 3: np.float64(0.92), 4: np.float64(0.75), 5: np.float64(0.952), 6: np.float64(0.927)}
# 0.854
# val_acc: 0.542
# epoch 35: 100% 32/32 [00:01<00:00, 19.95batch/s, loss=0.00382]
# val-epoch 35: 100% 6/6 [00:00<00:00, 10.97it/s]
# val_aupr: {0: np.float64(0.435), 1: np.float64(0.432), 2: np.float64(0.632), 3: np.float64(0.536), 4: np.float64(0.468), 5: np.float64(0.774), 6: np.float64(0.802)}
# 0.583
# val_auroc: {0: np.float64(0.733), 1: np.float64(0.876), 2: np.float64(0.809), 3: np.float64(0.911), 4: np.float64(0.752), 5: np.float64(0.95), 6: np.float64(0.926)}
# 0.851
# val_acc: 0.538
# epoch 40: 100% 32/32 [00:01<00:00, 19.19batch/s, loss=0.00248]
# val-epoch 40: 100% 6/6 [00:00<00:00, 10.75it/s]
# val_aupr: {0: np.float64(0.436), 1: np.float64(0.443), 2: np.float64(0.633), 3: np.float64(0.53), 4: np.float64(0.466), 5: np.float64(0.767), 6: np.float64(0.803)}
# 0.583
# val_auroc: {0: np.float64(0.741), 1: np.float64(0.878), 2: np.float64(0.81), 3: np.float64(0.914), 4: np.float64(0.748), 5: np.float64(0.945), 6: np.float64(0.926)}
# 0.852
# val_acc: 0.536
#
# Training lam0:
# epoch 0: 100% 32/32 [00:01<00:00, 19.33batch/s, ce_loss=1.14, lam_loss=0.121]
# val-epoch 0: 100% 6/6 [00:00<00:00, 10.83it/s]
# val_aupr: {0: np.float64(0.465), 1: np.float64(0.441), 2: np.float64(0.513), 3: np.float64(0.503), 4: np.float64(0.516), 5: np.float64(0.647), 6: np.float64(0.746)}
# 0.547
# val_auroc: {0: np.float64(0.781), 1: np.float64(0.922), 2: np.float64(0.768), 3: np.float64(0.942), 4: np.float64(0.806), 5: np.float64(0.93), 6: np.float64(0.928)}
# 0.868
# val_acc: 0.492
# epoch 5: 100% 32/32 [00:01<00:00, 19.10batch/s, ce_loss=0.101, lam_loss=0.256]
# val-epoch 5: 100% 6/6 [00:00<00:00, 10.81it/s]
# val_aupr: {0: np.float64(0.51), 1: np.float64(0.533), 2: np.float64(0.699), 3: np.float64(0.592), 4: np.float64(0.584), 5: np.float64(0.811), 6: np.float64(0.854)}
# 0.655
# val_auroc: {0: np.float64(0.805), 1: np.float64(0.925), 2: np.float64(0.86), 3: np.float64(0.954), 4: np.float64(0.83), 5: np.float64(0.973), 6: np.float64(0.958)}
# 0.901
# val_acc: 0.594
# epoch 10: 100% 32/32 [00:01<00:00, 19.63batch/s, ce_loss=0.0162, lam_loss=0.302]
# val-epoch 10: 100% 6/6 [00:00<00:00, 10.90it/s]
# val_aupr: {0: np.float64(0.528), 1: np.float64(0.552), 2: np.float64(0.701), 3: np.float64(0.588), 4: np.float64(0.566), 5: np.float64(0.8), 6: np.float64(0.849)}
# 0.655
# val_auroc: {0: np.float64(0.81), 1: np.float64(0.932), 2: np.float64(0.866), 3: np.float64(0.946), 4: np.float64(0.82), 5: np.float64(0.969), 6: np.float64(0.953)}
# 0.899
# val_acc: 0.601
# epoch 15: 100% 32/32 [00:01<00:00, 19.42batch/s, ce_loss=0.00543, lam_loss=0.33]
# val-epoch 15: 100% 6/6 [00:00<00:00, 11.09it/s]
# val_aupr: {0: np.float64(0.525), 1: np.float64(0.561), 2: np.float64(0.704), 3: np.float64(0.581), 4: np.float64(0.566), 5: np.float64(0.805), 6: np.float64(0.851)}
# 0.656
# val_auroc: {0: np.float64(0.808), 1: np.float64(0.932), 2: np.float64(0.862), 3: np.float64(0.945), 4: np.float64(0.82), 5: np.float64(0.971), 6: np.float64(0.953)}
# 0.899
# val_acc: 0.606
# epoch 20: 100% 32/32 [00:01<00:00, 19.75batch/s, ce_loss=0.00385, lam_loss=0.354]
# val-epoch 20: 100% 6/6 [00:00<00:00, 10.75it/s]
# val_aupr: {0: np.float64(0.519), 1: np.float64(0.563), 2: np.float64(0.701), 3: np.float64(0.574), 4: np.float64(0.562), 5: np.float64(0.796), 6: np.float64(0.848)}
# 0.652
# val_auroc: {0: np.float64(0.804), 1: np.float64(0.932), 2: np.float64(0.862), 3: np.float64(0.946), 4: np.float64(0.816), 5: np.float64(0.97), 6: np.float64(0.952)}
# 0.897
# val_acc: 0.609
# epoch 25: 100% 32/32 [00:01<00:00, 19.01batch/s, ce_loss=0.00237, lam_loss=0.341]
# val-epoch 25: 100% 6/6 [00:00<00:00, 10.86it/s]
# val_aupr: {0: np.float64(0.525), 1: np.float64(0.554), 2: np.float64(0.704), 3: np.float64(0.587), 4: np.float64(0.562), 5: np.float64(0.799), 6: np.float64(0.852)}
# 0.655
# val_auroc: {0: np.float64(0.806), 1: np.float64(0.93), 2: np.float64(0.863), 3: np.float64(0.942), 4: np.float64(0.813), 5: np.float64(0.969), 6: np.float64(0.954)}
# 0.897
# val_acc: 0.603
# epoch 30: 100% 32/32 [00:01<00:00, 19.41batch/s, ce_loss=0.00161, lam_loss=0.356]
# val-epoch 30: 100% 6/6 [00:00<00:00, 10.92it/s]
# val_aupr: {0: np.float64(0.525), 1: np.float64(0.56), 2: np.float64(0.703), 3: np.float64(0.577), 4: np.float64(0.563), 5: np.float64(0.793), 6: np.float64(0.849)}
# 0.653
# val_auroc: {0: np.float64(0.805), 1: np.float64(0.931), 2: np.float64(0.863), 3: np.float64(0.943), 4: np.float64(0.815), 5: np.float64(0.969), 6: np.float64(0.951)}
# 0.897
# val_acc: 0.606
# epoch 35: 100% 32/32 [00:01<00:00, 19.24batch/s, ce_loss=0.000923, lam_loss=0.359]
# val-epoch 35: 100% 6/6 [00:00<00:00, 11.19it/s]
# val_aupr: {0: np.float64(0.526), 1: np.float64(0.551), 2: np.float64(0.704), 3: np.float64(0.58), 4: np.float64(0.567), 5: np.float64(0.796), 6: np.float64(0.848)}
# 0.653
# val_auroc: {0: np.float64(0.805), 1: np.float64(0.927), 2: np.float64(0.865), 3: np.float64(0.942), 4: np.float64(0.815), 5: np.float64(0.968), 6: np.float64(0.951)}
# 0.896
# val_acc: 0.605
# epoch 40: 100% 32/32 [00:01<00:00, 18.97batch/s, ce_loss=0.001, lam_loss=0.347]
# val-epoch 40: 100% 6/6 [00:00<00:00, 11.10it/s]
# val_aupr: {0: np.float64(0.529), 1: np.float64(0.539), 2: np.float64(0.704), 3: np.float64(0.578), 4: np.float64(0.572), 5: np.float64(0.797), 6: np.float64(0.847)}
# 0.652
# val_auroc: {0: np.float64(0.804), 1: np.float64(0.924), 2: np.float64(0.863), 3: np.float64(0.942), 4: np.float64(0.816), 5: np.float64(0.969), 6: np.float64(0.951)}
# 0.896
# val_acc: 0.602
#
# Training lam1:
# epoch 0: 100% 32/32 [00:01<00:00, 19.13batch/s, ce_loss=1.27, lam_loss=0.133]
# val-epoch 0: 100% 6/6 [00:00<00:00, 11.07it/s]
# val_aupr: {0: np.float64(0.447), 1: np.float64(0.41), 2: np.float64(0.515), 3: np.float64(0.516), 4: np.float64(0.471), 5: np.float64(0.674), 6: np.float64(0.665)}
# 0.528
# val_auroc: {0: np.float64(0.773), 1: np.float64(0.915), 2: np.float64(0.752), 3: np.float64(0.94), 4: np.float64(0.78), 5: np.float64(0.937), 6: np.float64(0.913)}
# 0.859
# val_acc: 0.455
# epoch 5: 100% 32/32 [00:01<00:00, 19.03batch/s, ce_loss=0.122, lam_loss=0.257]
# val-epoch 5: 100% 6/6 [00:00<00:00, 11.00it/s]
# val_aupr: {0: np.float64(0.509), 1: np.float64(0.473), 2: np.float64(0.676), 3: np.float64(0.536), 4: np.float64(0.526), 5: np.float64(0.782), 6: np.float64(0.811)}
# 0.616
# val_auroc: {0: np.float64(0.814), 1: np.float64(0.907), 2: np.float64(0.846), 3: np.float64(0.939), 4: np.float64(0.804), 5: np.float64(0.96), 6: np.float64(0.948)}
# 0.888
# val_acc: 0.553
# epoch 10: 100% 32/32 [00:01<00:00, 19.29batch/s, ce_loss=0.0141, lam_loss=0.288]
# val-epoch 10: 100% 6/6 [00:00<00:00, 11.00it/s]
# val_aupr: {0: np.float64(0.494), 1: np.float64(0.48), 2: np.float64(0.68), 3: np.float64(0.558), 4: np.float64(0.517), 5: np.float64(0.775), 6: np.float64(0.816)}
# 0.617
# val_auroc: {0: np.float64(0.797), 1: np.float64(0.9), 2: np.float64(0.846), 3: np.float64(0.942), 4: np.float64(0.802), 5: np.float64(0.959), 6: np.float64(0.946)}
# 0.885
# val_acc: 0.552
# epoch 15: 100% 32/32 [00:01<00:00, 19.09batch/s, ce_loss=0.00505, lam_loss=0.313]
# val-epoch 15: 100% 6/6 [00:00<00:00, 10.94it/s]
# val_aupr: {0: np.float64(0.494), 1: np.float64(0.475), 2: np.float64(0.673), 3: np.float64(0.553), 4: np.float64(0.515), 5: np.float64(0.768), 6: np.float64(0.817)}
# 0.614
# val_auroc: {0: np.float64(0.79), 1: np.float64(0.899), 2: np.float64(0.844), 3: np.float64(0.941), 4: np.float64(0.801), 5: np.float64(0.956), 6: np.float64(0.945)}
# 0.882
# val_acc: 0.549
# epoch 20: 100% 32/32 [00:01<00:00, 19.29batch/s, ce_loss=0.00366, lam_loss=0.333]
# val-epoch 20: 100% 6/6 [00:00<00:00, 10.87it/s]
# val_aupr: {0: np.float64(0.501), 1: np.float64(0.489), 2: np.float64(0.669), 3: np.float64(0.566), 4: np.float64(0.515), 5: np.float64(0.769), 6: np.float64(0.813)}
# 0.617
# val_auroc: {0: np.float64(0.794), 1: np.float64(0.899), 2: np.float64(0.842), 3: np.float64(0.942), 4: np.float64(0.797), 5: np.float64(0.955), 6: np.float64(0.942)}
# 0.882
# val_acc: 0.546
# epoch 25: 100% 32/32 [00:01<00:00, 19.03batch/s, ce_loss=0.00219, lam_loss=0.329]
# val-epoch 25: 100% 6/6 [00:00<00:00, 11.11it/s]
# val_aupr: {0: np.float64(0.497), 1: np.float64(0.477), 2: np.float64(0.667), 3: np.float64(0.561), 4: np.float64(0.512), 5: np.float64(0.766), 6: np.float64(0.816)}
# 0.614
# val_auroc: {0: np.float64(0.791), 1: np.float64(0.896), 2: np.float64(0.843), 3: np.float64(0.94), 4: np.float64(0.796), 5: np.float64(0.953), 6: np.float64(0.943)}
# 0.88
# val_acc: 0.547
# epoch 30: 100% 32/32 [00:01<00:00, 19.24batch/s, ce_loss=0.00149, lam_loss=0.37]
# val-epoch 30: 100% 6/6 [00:00<00:00, 11.23it/s]
# val_aupr: {0: np.float64(0.5), 1: np.float64(0.482), 2: np.float64(0.668), 3: np.float64(0.556), 4: np.float64(0.509), 5: np.float64(0.765), 6: np.float64(0.811)}
# 0.613
# val_auroc: {0: np.float64(0.789), 1: np.float64(0.897), 2: np.float64(0.843), 3: np.float64(0.939), 4: np.float64(0.794), 5: np.float64(0.952), 6: np.float64(0.94)}
# 0.879
# val_acc: 0.559
# epoch 35: 100% 32/32 [00:01<00:00, 18.81batch/s, ce_loss=0.000896, lam_loss=0.351]
# val-epoch 35: 100% 6/6 [00:00<00:00, 10.76it/s]
# val_aupr: {0: np.float64(0.496), 1: np.float64(0.474), 2: np.float64(0.663), 3: np.float64(0.563), 4: np.float64(0.507), 5: np.float64(0.765), 6: np.float64(0.814)}
# 0.612
# val_auroc: {0: np.float64(0.785), 1: np.float64(0.893), 2: np.float64(0.842), 3: np.float64(0.938), 4: np.float64(0.793), 5: np.float64(0.952), 6: np.float64(0.941)}
# 0.878
# val_acc: 0.556
# epoch 40: 100% 32/32 [00:01<00:00, 19.59batch/s, ce_loss=0.000832, lam_loss=0.356]
# val-epoch 40: 100% 6/6 [00:00<00:00, 10.92it/s]
# val_aupr: {0: np.float64(0.498), 1: np.float64(0.478), 2: np.float64(0.664), 3: np.float64(0.552), 4: np.float64(0.508), 5: np.float64(0.772), 6: np.float64(0.81)}
# 0.612
# val_auroc: {0: np.float64(0.785), 1: np.float64(0.894), 2: np.float64(0.842), 3: np.float64(0.938), 4: np.float64(0.792), 5: np.float64(0.953), 6: np.float64(0.938)}
# 0.877
# val_acc: 0.549
#
# Training lam2:
# epoch 0: 100% 32/32 [00:01<00:00, 18.90batch/s, ce_loss=1.17, lam_loss=0.138]
# val-epoch 0: 100% 6/6 [00:00<00:00, 10.90it/s]
# val_aupr: {0: np.float64(0.487), 1: np.float64(0.434), 2: np.float64(0.555), 3: np.float64(0.445), 4: np.float64(0.54), 5: np.float64(0.62), 6: np.float64(0.763)}
# 0.549
# val_auroc: {0: np.float64(0.776), 1: np.float64(0.914), 2: np.float64(0.769), 3: np.float64(0.921), 4: np.float64(0.802), 5: np.float64(0.935), 6: np.float64(0.935)}
# 0.865
# val_acc: 0.48
# epoch 5: 100% 32/32 [00:01<00:00, 19.59batch/s, ce_loss=0.114, lam_loss=0.264]
# val-epoch 5: 100% 6/6 [00:00<00:00, 11.18it/s]
# val_aupr: {0: np.float64(0.517), 1: np.float64(0.524), 2: np.float64(0.689), 3: np.float64(0.539), 4: np.float64(0.567), 5: np.float64(0.786), 6: np.float64(0.832)}
# 0.636
# val_auroc: {0: np.float64(0.797), 1: np.float64(0.921), 2: np.float64(0.852), 3: np.float64(0.933), 4: np.float64(0.834), 5: np.float64(0.965), 6: np.float64(0.959)}
# 0.894
# val_acc: 0.578
# epoch 10: 100% 32/32 [00:01<00:00, 18.20batch/s, ce_loss=0.0119, lam_loss=0.292]
# val-epoch 10: 100% 6/6 [00:00<00:00, 11.02it/s]
# val_aupr: {0: np.float64(0.511), 1: np.float64(0.522), 2: np.float64(0.684), 3: np.float64(0.569), 4: np.float64(0.552), 5: np.float64(0.79), 6: np.float64(0.835)}
# 0.638
# val_auroc: {0: np.float64(0.789), 1: np.float64(0.917), 2: np.float64(0.847), 3: np.float64(0.938), 4: np.float64(0.825), 5: np.float64(0.964), 6: np.float64(0.957)}
# 0.891
# val_acc: 0.587
# epoch 15: 100% 32/32 [00:01<00:00, 19.00batch/s, ce_loss=0.00592, lam_loss=0.302]
# val-epoch 15: 100% 6/6 [00:00<00:00, 11.09it/s]
# val_aupr: {0: np.float64(0.5), 1: np.float64(0.524), 2: np.float64(0.685), 3: np.float64(0.569), 4: np.float64(0.554), 5: np.float64(0.794), 6: np.float64(0.834)}
# 0.637
# val_auroc: {0: np.float64(0.777), 1: np.float64(0.912), 2: np.float64(0.848), 3: np.float64(0.939), 4: np.float64(0.823), 5: np.float64(0.965), 6: np.float64(0.956)}
# 0.889
# val_acc: 0.591
# epoch 20: 100% 32/32 [00:01<00:00, 19.45batch/s, ce_loss=0.00348, lam_loss=0.326]
# val-epoch 20: 100% 6/6 [00:00<00:00, 10.89it/s]
# val_aupr: {0: np.float64(0.504), 1: np.float64(0.526), 2: np.float64(0.682), 3: np.float64(0.572), 4: np.float64(0.554), 5: np.float64(0.792), 6: np.float64(0.836)}
# 0.638
# val_auroc: {0: np.float64(0.782), 1: np.float64(0.912), 2: np.float64(0.846), 3: np.float64(0.94), 4: np.float64(0.822), 5: np.float64(0.965), 6: np.float64(0.957)}
# 0.889
# val_acc: 0.585
# epoch 25: 100% 32/32 [00:01<00:00, 19.59batch/s, ce_loss=0.00205, lam_loss=0.325]
# val-epoch 25: 100% 6/6 [00:00<00:00, 10.87it/s]
# val_aupr: {0: np.float64(0.503), 1: np.float64(0.53), 2: np.float64(0.687), 3: np.float64(0.579), 4: np.float64(0.556), 5: np.float64(0.789), 6: np.float64(0.836)}
# 0.64
# val_auroc: {0: np.float64(0.783), 1: np.float64(0.912), 2: np.float64(0.849), 3: np.float64(0.939), 4: np.float64(0.823), 5: np.float64(0.963), 6: np.float64(0.956)}
# 0.889
# val_acc: 0.588
# epoch 30: 100% 32/32 [00:01<00:00, 18.96batch/s, ce_loss=0.00166, lam_loss=0.328]
# val-epoch 30: 100% 6/6 [00:00<00:00, 10.78it/s]
# val_aupr: {0: np.float64(0.492), 1: np.float64(0.528), 2: np.float64(0.679), 3: np.float64(0.556), 4: np.float64(0.55), 5: np.float64(0.786), 6: np.float64(0.834)}
# 0.632
# val_auroc: {0: np.float64(0.779), 1: np.float64(0.911), 2: np.float64(0.845), 3: np.float64(0.939), 4: np.float64(0.818), 5: np.float64(0.964), 6: np.float64(0.957)}
# 0.888
# val_acc: 0.582
# epoch 35: 100% 32/32 [00:01<00:00, 19.52batch/s, ce_loss=0.00124, lam_loss=0.306]
# val-epoch 35: 100% 6/6 [00:00<00:00, 10.92it/s]
# val_aupr: {0: np.float64(0.497), 1: np.float64(0.532), 2: np.float64(0.682), 3: np.float64(0.573), 4: np.float64(0.551), 5: np.float64(0.792), 6: np.float64(0.835)}
# 0.637
# val_auroc: {0: np.float64(0.78), 1: np.float64(0.91), 2: np.float64(0.846), 3: np.float64(0.941), 4: np.float64(0.819), 5: np.float64(0.965), 6: np.float64(0.956)}
# 0.888
# val_acc: 0.585
# epoch 40: 100% 32/32 [00:01<00:00, 19.37batch/s, ce_loss=0.00135, lam_loss=0.309]
# val-epoch 40: 100% 6/6 [00:00<00:00, 10.83it/s]
# val_aupr: {0: np.float64(0.497), 1: np.float64(0.531), 2: np.float64(0.68), 3: np.float64(0.572), 4: np.float64(0.55), 5: np.float64(0.79), 6: np.float64(0.835)}
# 0.636
# val_auroc: {0: np.float64(0.779), 1: np.float64(0.911), 2: np.float64(0.844), 3: np.float64(0.94), 4: np.float64(0.818), 5: np.float64(0.964), 6: np.float64(0.957)}
# 0.888
# val_acc: 0.581
#
# Training lam3:
# epoch 0: 100% 32/32 [00:01<00:00, 19.17batch/s, ce_loss=1.35, lam_loss=0.138]
# val-epoch 0: 100% 6/6 [00:00<00:00, 10.90it/s]
# val_aupr: {0: np.float64(0.428), 1: np.float64(0.436), 2: np.float64(0.525), 3: np.float64(0.558), 4: np.float64(0.49), 5: np.float64(0.682), 6: np.float64(0.649)}
# 0.538
# val_auroc: {0: np.float64(0.76), 1: np.float64(0.917), 2: np.float64(0.76), 3: np.float64(0.946), 4: np.float64(0.785), 5: np.float64(0.92), 6: np.float64(0.914)}
# 0.857
# val_acc: 0.49
# epoch 5: 100% 32/32 [00:01<00:00, 19.39batch/s, ce_loss=0.157, lam_loss=0.257]
# val-epoch 5: 100% 6/6 [00:00<00:00, 11.07it/s]
# val_aupr: {0: np.float64(0.497), 1: np.float64(0.538), 2: np.float64(0.659), 3: np.float64(0.625), 4: np.float64(0.534), 5: np.float64(0.805), 6: np.float64(0.854)}
# 0.645
# val_auroc: {0: np.float64(0.795), 1: np.float64(0.928), 2: np.float64(0.835), 3: np.float64(0.954), 4: np.float64(0.812), 5: np.float64(0.966), 6: np.float64(0.959)}
# 0.893
# val_acc: 0.563
# epoch 10: 100% 32/32 [00:01<00:00, 19.26batch/s, ce_loss=0.0155, lam_loss=0.244]
# val-epoch 10: 100% 6/6 [00:00<00:00, 10.67it/s]
# val_aupr: {0: np.float64(0.5), 1: np.float64(0.519), 2: np.float64(0.657), 3: np.float64(0.617), 4: np.float64(0.526), 5: np.float64(0.838), 6: np.float64(0.852)}
# 0.644
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.921), 2: np.float64(0.847), 3: np.float64(0.95), 4: np.float64(0.802), 5: np.float64(0.967), 6: np.float64(0.956)}
# 0.891
# val_acc: 0.571
# epoch 15: 100% 32/32 [00:01<00:00, 19.26batch/s, ce_loss=0.00956, lam_loss=0.225]
# val-epoch 15: 100% 6/6 [00:00<00:00, 10.70it/s]
# val_aupr: {0: np.float64(0.502), 1: np.float64(0.524), 2: np.float64(0.652), 3: np.float64(0.622), 4: np.float64(0.526), 5: np.float64(0.822), 6: np.float64(0.853)}
# 0.643
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.923), 2: np.float64(0.84), 3: np.float64(0.953), 4: np.float64(0.799), 5: np.float64(0.964), 6: np.float64(0.957)}
# 0.89
# val_acc: 0.57
# epoch 20: 100% 32/32 [00:01<00:00, 19.62batch/s, ce_loss=0.00632, lam_loss=0.197]
# val-epoch 20: 100% 6/6 [00:00<00:00, 11.01it/s]
# val_aupr: {0: np.float64(0.508), 1: np.float64(0.534), 2: np.float64(0.645), 3: np.float64(0.613), 4: np.float64(0.525), 5: np.float64(0.815), 6: np.float64(0.853)}
# 0.642
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.923), 2: np.float64(0.839), 3: np.float64(0.952), 4: np.float64(0.801), 5: np.float64(0.961), 6: np.float64(0.957)}
# 0.889
# val_acc: 0.567
# epoch 25: 100% 32/32 [00:01<00:00, 19.34batch/s, ce_loss=0.00384, lam_loss=0.172]
# val-epoch 25: 100% 6/6 [00:00<00:00, 11.24it/s]
# val_aupr: {0: np.float64(0.503), 1: np.float64(0.537), 2: np.float64(0.65), 3: np.float64(0.614), 4: np.float64(0.534), 5: np.float64(0.816), 6: np.float64(0.853)}
# 0.644
# val_auroc: {0: np.float64(0.793), 1: np.float64(0.924), 2: np.float64(0.839), 3: np.float64(0.954), 4: np.float64(0.803), 5: np.float64(0.962), 6: np.float64(0.956)}
# 0.89
# val_acc: 0.571
# epoch 30: 100% 32/32 [00:01<00:00, 19.22batch/s, ce_loss=0.00322, lam_loss=0.138]
# val-epoch 30: 100% 6/6 [00:00<00:00, 10.77it/s]
# val_aupr: {0: np.float64(0.509), 1: np.float64(0.538), 2: np.float64(0.655), 3: np.float64(0.62), 4: np.float64(0.537), 5: np.float64(0.836), 6: np.float64(0.847)}
# 0.649
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.925), 2: np.float64(0.841), 3: np.float64(0.953), 4: np.float64(0.804), 5: np.float64(0.967), 6: np.float64(0.956)}
# 0.891
# val_acc: 0.571
# epoch 35: 100% 32/32 [00:01<00:00, 19.46batch/s, ce_loss=0.00364, lam_loss=0.129]
# val-epoch 35: 100% 6/6 [00:00<00:00, 11.01it/s]
# val_aupr: {0: np.float64(0.506), 1: np.float64(0.534), 2: np.float64(0.654), 3: np.float64(0.605), 4: np.float64(0.542), 5: np.float64(0.822), 6: np.float64(0.851)}
# 0.645
# val_auroc: {0: np.float64(0.793), 1: np.float64(0.924), 2: np.float64(0.842), 3: np.float64(0.951), 4: np.float64(0.808), 5: np.float64(0.962), 6: np.float64(0.956)}
# 0.891
# val_acc: 0.574
# epoch 40: 100% 32/32 [00:01<00:00, 19.34batch/s, ce_loss=0.00288, lam_loss=0.107]
# val-epoch 40: 100% 6/6 [00:00<00:00, 11.08it/s]
# val_aupr: {0: np.float64(0.511), 1: np.float64(0.541), 2: np.float64(0.658), 3: np.float64(0.611), 4: np.float64(0.538), 5: np.float64(0.829), 6: np.float64(0.851)}
# 0.648
# val_auroc: {0: np.float64(0.796), 1: np.float64(0.924), 2: np.float64(0.842), 3: np.float64(0.951), 4: np.float64(0.805), 5: np.float64(0.964), 6: np.float64(0.957)}
# 0.891
# val_acc: 0.574
#
# Training clear:
# Epoch 0: 100% 32/32 [00:01<00:00, 17.11batch/s, c_loss=1.53, kl_c=14.3, kl_s=10.4, recontr_loss=2.25e+3, s_loss=0.165]
# val-epoch 0: 100% 6/6 [00:00<00:00, 10.55it/s]
# val_recontr_loss=2233.981, val_kl_c=3.551, val_kl_s=2.759, val_c_loss=1.650, val_s_loss=0.213
# gMIG: 0.004; mse: 2233.981
# Epoch 5: 100% 32/32 [00:01<00:00, 19.49batch/s, c_loss=1.08, kl_c=19, kl_s=33, recontr_loss=1.35e+3, s_loss=0.164]
# val-epoch 5: 100% 6/6 [00:00<00:00, 10.95it/s]
# val_recontr_loss=1502.831, val_kl_c=18.630, val_kl_s=34.274, val_c_loss=1.301, val_s_loss=0.168
# gMIG: -0.011; mse: 1502.831
# Epoch 10: 100% 32/32 [00:01<00:00, 18.95batch/s, c_loss=0.529, kl_c=29, kl_s=54.5, recontr_loss=1.27e+3, s_loss=0.167]
# val-epoch 10: 100% 6/6 [00:00<00:00, 10.91it/s]
# val_recontr_loss=1244.869, val_kl_c=27.541, val_kl_s=51.797, val_c_loss=1.328, val_s_loss=0.169
# gMIG: -0.04; mse: 1244.869
# Epoch 15: 100% 32/32 [00:01<00:00, 18.81batch/s, c_loss=0.187, kl_c=37.7, kl_s=66.8, recontr_loss=1.3e+3, s_loss=0.163]
# val-epoch 15: 100% 6/6 [00:00<00:00, 10.74it/s]
# val_recontr_loss=1210.914, val_kl_c=37.064, val_kl_s=65.279, val_c_loss=1.327, val_s_loss=0.170
# gMIG: -0.039; mse: 1210.914
# Epoch 20: 100% 32/32 [00:01<00:00, 18.65batch/s, c_loss=0.0472, kl_c=46.2, kl_s=77.5, recontr_loss=1.11e+3, s_loss=0.162]
# val-epoch 20: 100% 6/6 [00:00<00:00, 10.77it/s]
# val_recontr_loss=1174.154, val_kl_c=45.448, val_kl_s=76.344, val_c_loss=1.310, val_s_loss=0.172
# gMIG: -0.037; mse: 1174.154
# Epoch 25: 100% 32/32 [00:01<00:00, 19.09batch/s, c_loss=0.0279, kl_c=51.9, kl_s=84.9, recontr_loss=1.14e+3, s_loss=0.174]
# val-epoch 25: 100% 6/6 [00:00<00:00, 10.99it/s]
# val_recontr_loss=1186.160, val_kl_c=51.851, val_kl_s=84.931, val_c_loss=1.318, val_s_loss=0.173
# gMIG: -0.033; mse: 1186.16
# Epoch 30: 100% 32/32 [00:01<00:00, 19.32batch/s, c_loss=0.0202, kl_c=57, kl_s=89.8, recontr_loss=1.06e+3, s_loss=0.169]
# val-epoch 30: 100% 6/6 [00:00<00:00, 10.97it/s]
# val_recontr_loss=1154.352, val_kl_c=56.420, val_kl_s=88.484, val_c_loss=1.301, val_s_loss=0.172
# gMIG: -0.019; mse: 1154.352
# Epoch 35: 100% 32/32 [00:01<00:00, 19.46batch/s, c_loss=0.0157, kl_c=61.5, kl_s=94.2, recontr_loss=1.13e+3, s_loss=0.164]
# val-epoch 35: 100% 6/6 [00:00<00:00, 11.10it/s]
# val_recontr_loss=1160.104, val_kl_c=61.386, val_kl_s=94.169, val_c_loss=1.318, val_s_loss=0.172
# gMIG: -0.02; mse: 1160.104
# Epoch 40: 100% 32/32 [00:01<00:00, 19.10batch/s, c_loss=0.0158, kl_c=65.2, kl_s=96.9, recontr_loss=1.04e+3, s_loss=0.155]
# val-epoch 40: 100% 6/6 [00:00<00:00, 10.86it/s]
# val_recontr_loss=1101.346, val_kl_c=63.967, val_kl_s=94.648, val_c_loss=1.305, val_s_loss=0.172
# gMIG: -0.011; mse: 1101.346
# epoch 0: 100% 32/32 [00:01<00:00, 19.45batch/s, loss=1.27]
# val-epoch 0: 100% 6/6 [00:00<00:00, 10.62it/s]
# val_aupr: {0: np.float64(0.425), 1: np.float64(0.433), 2: np.float64(0.521), 3: np.float64(0.43), 4: np.float64(0.46), 5: np.float64(0.606), 6: np.float64(0.532)}
# 0.487
# val_auroc: {0: np.float64(0.723), 1: np.float64(0.868), 2: np.float64(0.756), 3: np.float64(0.805), 4: np.float64(0.75), 5: np.float64(0.907), 6: np.float64(0.81)}
# 0.803
# val_acc: 0.454
# epoch 10: 100% 32/32 [00:01<00:00, 19.38batch/s, loss=0.0458]
# val-epoch 10: 100% 6/6 [00:00<00:00, 10.80it/s]
# val_aupr: {0: np.float64(0.469), 1: np.float64(0.477), 2: np.float64(0.604), 3: np.float64(0.507), 4: np.float64(0.515), 5: np.float64(0.674), 6: np.float64(0.757)}
# 0.572
# val_auroc: {0: np.float64(0.769), 1: np.float64(0.88), 2: np.float64(0.803), 3: np.float64(0.886), 4: np.float64(0.785), 5: np.float64(0.924), 6: np.float64(0.895)}
# 0.849
# val_acc: 0.522
# epoch 20: 100% 32/32 [00:01<00:00, 20.16batch/s, loss=0.0129]
# val-epoch 20: 100% 6/6 [00:00<00:00, 10.84it/s]
# val_aupr: {0: np.float64(0.466), 1: np.float64(0.47), 2: np.float64(0.607), 3: np.float64(0.505), 4: np.float64(0.515), 5: np.float64(0.674), 6: np.float64(0.758)}
# 0.571
# val_auroc: {0: np.float64(0.767), 1: np.float64(0.877), 2: np.float64(0.803), 3: np.float64(0.891), 4: np.float64(0.783), 5: np.float64(0.924), 6: np.float64(0.889)}
# 0.848
# val_acc: 0.524
# epoch 30: 100% 32/32 [00:01<00:00, 19.75batch/s, loss=0.0133]
# val-epoch 30: 100% 6/6 [00:00<00:00, 11.24it/s]
# val_aupr: {0: np.float64(0.468), 1: np.float64(0.475), 2: np.float64(0.608), 3: np.float64(0.5), 4: np.float64(0.515), 5: np.float64(0.672), 6: np.float64(0.759)}
# 0.571
# val_auroc: {0: np.float64(0.769), 1: np.float64(0.878), 2: np.float64(0.804), 3: np.float64(0.891), 4: np.float64(0.782), 5: np.float64(0.921), 6: np.float64(0.889)}
# 0.848
# val_acc: 0.529
# epoch 40: 100% 32/32 [00:01<00:00, 19.37batch/s, loss=0.00436]
# val-epoch 40: 100% 6/6 [00:00<00:00, 11.15it/s]
# val_aupr: {0: np.float64(0.467), 1: np.float64(0.475), 2: np.float64(0.61), 3: np.float64(0.5), 4: np.float64(0.517), 5: np.float64(0.669), 6: np.float64(0.758)}
# 0.571
# val_auroc: {0: np.float64(0.768), 1: np.float64(0.875), 2: np.float64(0.804), 3: np.float64(0.892), 4: np.float64(0.783), 5: np.float64(0.921), 6: np.float64(0.887)}
# 0.847
# val_acc: 0.528
#
# Results:
# {
#   "baseline": {
#     "acc": 0.118,
#     "pr": {
#       "overall": 0.141,
#       "stratified": {
#         "0": 0.124,
#         "1": 0.219,
#         "2": 0.107,
#         "3": 0.106,
#         "4": 0.1,
#         "5": 0.152,
#         "6": 0.176
#       }
#     },
#     "roc": {
#       "overall": 0.507,
#       "stratified": {
#         "0": 0.457,
#         "1": 0.452,
#         "2": 0.531,
#         "3": 0.365,
#         "4": 0.536,
#         "5": 0.646,
#         "6": 0.562
#       }
#     }
#   },
#   "lam0": {
#     "acc": 0.138,
#     "pr": {
#       "overall": 0.147,
#       "stratified": {
#         "0": 0.114,
#         "1": 0.243,
#         "2": 0.119,
#         "3": 0.143,
#         "4": 0.099,
#         "5": 0.128,
#         "6": 0.186
#       }
#     },
#     "roc": {
#       "overall": 0.513,
#       "stratified": {
#         "0": 0.406,
#         "1": 0.428,
#         "2": 0.56,
#         "3": 0.511,
#         "4": 0.526,
#         "5": 0.591,
#         "6": 0.566
#       }
#     }
#   },
#   "lam1": {
#     "acc": 0.127,
#     "pr": {
#       "overall": 0.14,
#       "stratified": {
#         "0": 0.122,
#         "1": 0.228,
#         "2": 0.101,
#         "3": 0.109,
#         "4": 0.104,
#         "5": 0.128,
#         "6": 0.191
#       }
#     },
#     "roc": {
#       "overall": 0.501,
#       "stratified": {
#         "0": 0.444,
#         "1": 0.42,
#         "2": 0.523,
#         "3": 0.391,
#         "4": 0.539,
#         "5": 0.596,
#         "6": 0.591
#       }
#     }
#   },
#   "lam2": {
#     "acc": 0.12,
#     "pr": {
#       "overall": 0.137,
#       "stratified": {
#         "0": 0.118,
#         "1": 0.212,
#         "2": 0.124,
#         "3": 0.105,
#         "4": 0.105,
#         "5": 0.111,
#         "6": 0.182
#       }
#     },
#     "roc": {
#       "overall": 0.493,
#       "stratified": {
#         "0": 0.42,
#         "1": 0.413,
#         "2": 0.584,
#         "3": 0.367,
#         "4": 0.545,
#         "5": 0.548,
#         "6": 0.572
#       }
#     }
#   },
#   "lam3": {
#     "acc": 0.124,
#     "pr": {
#       "overall": 0.137,
#       "stratified": {
#         "0": 0.117,
#         "1": 0.195,
#         "2": 0.116,
#         "3": 0.121,
#         "4": 0.1,
#         "5": 0.129,
#         "6": 0.183
#       }
#     },
#     "roc": {
#       "overall": 0.498,
#       "stratified": {
#         "0": 0.419,
#         "1": 0.369,
#         "2": 0.568,
#         "3": 0.437,
#         "4": 0.518,
#         "5": 0.605,
#         "6": 0.573
#       }
#     }
#   },
#   "clear": {
#     "acc": 0.111,
#     "pr": {
#       "overall": 0.14,
#       "stratified": {
#         "0": 0.117,
#         "1": 0.236,
#         "2": 0.096,
#         "3": 0.104,
#         "4": 0.108,
#         "5": 0.163,
#         "6": 0.155
#       }
#     },
#     "roc": {
#       "overall": 0.496,
#       "stratified": {
#         "0": 0.416,
#         "1": 0.496,
#         "2": 0.491,
#         "3": 0.343,
#         "4": 0.562,
#         "5": 0.653,
#         "6": 0.51
#       }
#     }
#   }
# }
# Experiment: k=3, seed=76
# {0: {'test': ['art_painting'], 'train': ['photo', 'sketch', 'cartoon']},
#  1: {'test': ['photo'], 'train': ['art_painting', 'cartoon', 'sketch']},
#  2: {'test': ['cartoon'], 'train': ['art_painting', 'photo', 'sketch']},
#  3: {'test': ['photo'], 'train': ['sketch', 'art_painting', 'cartoon']},
#  4: {'test': ['cartoon'], 'train': ['art_painting', 'sketch', 'photo']},
#  5: {'test': ['art_painting'], 'train': ['cartoon', 'sketch', 'photo']},
#  6: {'test': ['cartoon'], 'train': ['sketch', 'photo', 'art_painting']}}
#
# Training baseline:
# epoch 0: 100% 53/53 [00:02<00:00, 21.08batch/s, loss=1.62]
# val-epoch 0: 100% 10/10 [00:00<00:00, 13.78it/s]
# val_aupr: {0: np.float64(0.397), 1: np.float64(0.706), 2: np.float64(0.485), 3: np.float64(0.856), 4: np.float64(0.391), 5: np.float64(0.626), 6: np.float64(0.817)}
# 0.611
# val_auroc: {0: np.float64(0.769), 1: np.float64(0.856), 2: np.float64(0.804), 3: np.float64(0.956), 4: np.float64(0.763), 5: np.float64(0.927), 6: np.float64(0.96)}
# 0.862
# val_acc: 0.52
# epoch 5: 100% 53/53 [00:02<00:00, 19.27batch/s, loss=0.281]
# val-epoch 5: 100% 10/10 [00:00<00:00, 13.84it/s]
# val_aupr: {0: np.float64(0.404), 1: np.float64(0.762), 2: np.float64(0.58), 3: np.float64(0.854), 4: np.float64(0.445), 5: np.float64(0.712), 6: np.float64(0.784)}
# 0.649
# val_auroc: {0: np.float64(0.796), 1: np.float64(0.896), 2: np.float64(0.835), 3: np.float64(0.935), 4: np.float64(0.796), 5: np.float64(0.941), 6: np.float64(0.952)}
# 0.879
# val_acc: 0.593
# epoch 10: 100% 53/53 [00:02<00:00, 21.49batch/s, loss=0.0317]
# val-epoch 10: 100% 10/10 [00:00<00:00, 13.95it/s]
# val_aupr: {0: np.float64(0.423), 1: np.float64(0.765), 2: np.float64(0.595), 3: np.float64(0.86), 4: np.float64(0.463), 5: np.float64(0.71), 6: np.float64(0.787)}
# 0.658
# val_auroc: {0: np.float64(0.806), 1: np.float64(0.897), 2: np.float64(0.845), 3: np.float64(0.933), 4: np.float64(0.805), 5: np.float64(0.943), 6: np.float64(0.952)}
# 0.883
# val_acc: 0.605
# epoch 15: 100% 53/53 [00:02<00:00, 19.41batch/s, loss=0.0183]
# val-epoch 15: 100% 10/10 [00:00<00:00, 13.28it/s]
# val_aupr: {0: np.float64(0.416), 1: np.float64(0.765), 2: np.float64(0.596), 3: np.float64(0.852), 4: np.float64(0.466), 5: np.float64(0.693), 6: np.float64(0.798)}
# 0.655
# val_auroc: {0: np.float64(0.803), 1: np.float64(0.9), 2: np.float64(0.847), 3: np.float64(0.927), 4: np.float64(0.805), 5: np.float64(0.942), 6: np.float64(0.949)}
# 0.882
# val_acc: 0.6
# epoch 20: 100% 53/53 [00:02<00:00, 19.10batch/s, loss=0.0294]
# val-epoch 20: 100% 10/10 [00:00<00:00, 13.95it/s]
# val_aupr: {0: np.float64(0.421), 1: np.float64(0.763), 2: np.float64(0.589), 3: np.float64(0.851), 4: np.float64(0.464), 5: np.float64(0.694), 6: np.float64(0.798)}
# 0.654
# val_auroc: {0: np.float64(0.803), 1: np.float64(0.899), 2: np.float64(0.84), 3: np.float64(0.93), 4: np.float64(0.804), 5: np.float64(0.942), 6: np.float64(0.947)}
# 0.881
# val_acc: 0.598
# epoch 25: 100% 53/53 [00:02<00:00, 19.48batch/s, loss=0.00683]
# val-epoch 25: 100% 10/10 [00:00<00:00, 13.99it/s]
# val_aupr: {0: np.float64(0.417), 1: np.float64(0.769), 2: np.float64(0.599), 3: np.float64(0.85), 4: np.float64(0.458), 5: np.float64(0.698), 6: np.float64(0.793)}
# 0.655
# val_auroc: {0: np.float64(0.801), 1: np.float64(0.901), 2: np.float64(0.845), 3: np.float64(0.928), 4: np.float64(0.806), 5: np.float64(0.941), 6: np.float64(0.949)}
# 0.882
# val_acc: 0.601
# epoch 30: 100% 53/53 [00:02<00:00, 21.33batch/s, loss=0.0724]
# val-epoch 30: 100% 10/10 [00:00<00:00, 13.64it/s]
# val_aupr: {0: np.float64(0.333), 1: np.float64(0.674), 2: np.float64(0.47), 3: np.float64(0.821), 4: np.float64(0.359), 5: np.float64(0.577), 6: np.float64(0.742)}
# 0.568
# val_auroc: {0: np.float64(0.722), 1: np.float64(0.85), 2: np.float64(0.792), 3: np.float64(0.918), 4: np.float64(0.73), 5: np.float64(0.908), 6: np.float64(0.935)}
# 0.836
# val_acc: 0.522
# epoch 35: 100% 53/53 [00:02<00:00, 19.64batch/s, loss=0.167]
# val-epoch 35: 100% 10/10 [00:00<00:00, 13.87it/s]
# val_aupr: {0: np.float64(0.408), 1: np.float64(0.768), 2: np.float64(0.581), 3: np.float64(0.846), 4: np.float64(0.46), 5: np.float64(0.684), 6: np.float64(0.788)}
# 0.648
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.895), 2: np.float64(0.834), 3: np.float64(0.928), 4: np.float64(0.799), 5: np.float64(0.945), 6: np.float64(0.948)}
# 0.877
# val_acc: 0.574
# epoch 40: 100% 53/53 [00:02<00:00, 19.38batch/s, loss=0.00564]
# val-epoch 40: 100% 10/10 [00:00<00:00, 13.70it/s]
# val_aupr: {0: np.float64(0.407), 1: np.float64(0.766), 2: np.float64(0.592), 3: np.float64(0.84), 4: np.float64(0.473), 5: np.float64(0.684), 6: np.float64(0.779)}
# 0.649
# val_auroc: {0: np.float64(0.787), 1: np.float64(0.897), 2: np.float64(0.841), 3: np.float64(0.921), 4: np.float64(0.801), 5: np.float64(0.94), 6: np.float64(0.946)}
# 0.876
# val_acc: 0.578
#
# Training lam0:
# epoch 0: 100% 53/53 [00:02<00:00, 20.77batch/s, ce_loss=1.17, lam_loss=0.0999]
# val-epoch 0: 100% 10/10 [00:00<00:00, 13.05it/s]
# val_aupr: {0: np.float64(0.375), 1: np.float64(0.705), 2: np.float64(0.454), 3: np.float64(0.86), 4: np.float64(0.405), 5: np.float64(0.657), 6: np.float64(0.79)}
# 0.607
# val_auroc: {0: np.float64(0.765), 1: np.float64(0.857), 2: np.float64(0.76), 3: np.float64(0.96), 4: np.float64(0.778), 5: np.float64(0.93), 6: np.float64(0.949)}
# 0.857
# val_acc: 0.514
# epoch 5: 100% 53/53 [00:02<00:00, 19.13batch/s, ce_loss=0.0591, lam_loss=0.201]
# val-epoch 5: 100% 10/10 [00:00<00:00, 13.65it/s]
# val_aupr: {0: np.float64(0.448), 1: np.float64(0.761), 2: np.float64(0.594), 3: np.float64(0.867), 4: np.float64(0.475), 5: np.float64(0.774), 6: np.float64(0.826)}
# 0.678
# val_auroc: {0: np.float64(0.808), 1: np.float64(0.897), 2: np.float64(0.849), 3: np.float64(0.96), 4: np.float64(0.808), 5: np.float64(0.958), 6: np.float64(0.96)}
# 0.891
# val_acc: 0.593
# epoch 10: 100% 53/53 [00:02<00:00, 19.43batch/s, ce_loss=0.0236, lam_loss=0.306]
# val-epoch 10: 100% 10/10 [00:00<00:00, 13.77it/s]
# val_aupr: {0: np.float64(0.444), 1: np.float64(0.764), 2: np.float64(0.586), 3: np.float64(0.865), 4: np.float64(0.493), 5: np.float64(0.784), 6: np.float64(0.834)}
# 0.681
# val_auroc: {0: np.float64(0.813), 1: np.float64(0.898), 2: np.float64(0.849), 3: np.float64(0.956), 4: np.float64(0.82), 5: np.float64(0.956), 6: np.float64(0.958)}
# 0.893
# val_acc: 0.602
# epoch 15: 100% 53/53 [00:02<00:00, 18.95batch/s, ce_loss=0.0146, lam_loss=0.288]
# val-epoch 15: 100% 10/10 [00:00<00:00, 13.88it/s]
# val_aupr: {0: np.float64(0.437), 1: np.float64(0.751), 2: np.float64(0.575), 3: np.float64(0.86), 4: np.float64(0.503), 5: np.float64(0.788), 6: np.float64(0.827)}
# 0.677
# val_auroc: {0: np.float64(0.812), 1: np.float64(0.892), 2: np.float64(0.842), 3: np.float64(0.954), 4: np.float64(0.817), 5: np.float64(0.958), 6: np.float64(0.955)}
# 0.89
# val_acc: 0.612
# epoch 20: 100% 53/53 [00:02<00:00, 19.11batch/s, ce_loss=0.00267, lam_loss=0.351]
# val-epoch 20: 100% 10/10 [00:00<00:00, 13.97it/s]
# val_aupr: {0: np.float64(0.437), 1: np.float64(0.76), 2: np.float64(0.585), 3: np.float64(0.86), 4: np.float64(0.501), 5: np.float64(0.787), 6: np.float64(0.827)}
# 0.68
# val_auroc: {0: np.float64(0.811), 1: np.float64(0.896), 2: np.float64(0.847), 3: np.float64(0.952), 4: np.float64(0.816), 5: np.float64(0.958), 6: np.float64(0.956)}
# 0.891
# val_acc: 0.604
# epoch 25: 100% 53/53 [00:02<00:00, 18.76batch/s, ce_loss=0.0119, lam_loss=0.422]
# val-epoch 25: 100% 10/10 [00:00<00:00, 13.55it/s]
# val_aupr: {0: np.float64(0.436), 1: np.float64(0.762), 2: np.float64(0.587), 3: np.float64(0.86), 4: np.float64(0.494), 5: np.float64(0.782), 6: np.float64(0.824)}
# 0.678
# val_auroc: {0: np.float64(0.808), 1: np.float64(0.896), 2: np.float64(0.848), 3: np.float64(0.952), 4: np.float64(0.817), 5: np.float64(0.956), 6: np.float64(0.955)}
# 0.89
# val_acc: 0.604
# epoch 30: 100% 53/53 [00:02<00:00, 20.36batch/s, ce_loss=0.026, lam_loss=0.437]
# val-epoch 30: 100% 10/10 [00:00<00:00, 13.57it/s]
# val_aupr: {0: np.float64(0.392), 1: np.float64(0.744), 2: np.float64(0.543), 3: np.float64(0.848), 4: np.float64(0.456), 5: np.float64(0.759), 6: np.float64(0.792)}
# 0.648
# val_auroc: {0: np.float64(0.775), 1: np.float64(0.877), 2: np.float64(0.838), 3: np.float64(0.956), 4: np.float64(0.806), 5: np.float64(0.942), 6: np.float64(0.938)}
# 0.876
# val_acc: 0.55
# epoch 35: 100% 53/53 [00:02<00:00, 20.47batch/s, ce_loss=0.0026, lam_loss=0.389]
# val-epoch 35: 100% 10/10 [00:00<00:00, 13.67it/s]
# val_aupr: {0: np.float64(0.412), 1: np.float64(0.752), 2: np.float64(0.574), 3: np.float64(0.856), 4: np.float64(0.453), 5: np.float64(0.769), 6: np.float64(0.818)}
# 0.662
# val_auroc: {0: np.float64(0.792), 1: np.float64(0.893), 2: np.float64(0.839), 3: np.float64(0.951), 4: np.float64(0.807), 5: np.float64(0.949), 6: np.float64(0.948)}
# 0.883
# val_acc: 0.588
# epoch 40: 100% 53/53 [00:02<00:00, 21.30batch/s, ce_loss=0.00102, lam_loss=0.356]
# val-epoch 40: 100% 10/10 [00:00<00:00, 13.97it/s]
# val_aupr: {0: np.float64(0.418), 1: np.float64(0.758), 2: np.float64(0.578), 3: np.float64(0.859), 4: np.float64(0.469), 5: np.float64(0.767), 6: np.float64(0.818)}
# 0.667
# val_auroc: {0: np.float64(0.797), 1: np.float64(0.896), 2: np.float64(0.84), 3: np.float64(0.95), 4: np.float64(0.813), 5: np.float64(0.951), 6: np.float64(0.949)}
# 0.885
# val_acc: 0.591
#
# Training lam1:
# epoch 0: 100% 53/53 [00:02<00:00, 19.42batch/s, ce_loss=0.89, lam_loss=0.0876]
# val-epoch 0: 100% 10/10 [00:00<00:00, 13.93it/s]
# val_aupr: {0: np.float64(0.416), 1: np.float64(0.7), 2: np.float64(0.459), 3: np.float64(0.854), 4: np.float64(0.442), 5: np.float64(0.698), 6: np.float64(0.822)}
# 0.627
# val_auroc: {0: np.float64(0.79), 1: np.float64(0.862), 2: np.float64(0.775), 3: np.float64(0.959), 4: np.float64(0.793), 5: np.float64(0.942), 6: np.float64(0.96)}
# 0.869
# val_acc: 0.545
# epoch 5: 100% 53/53 [00:02<00:00, 20.75batch/s, ce_loss=0.157, lam_loss=0.265]
# val-epoch 5: 100% 10/10 [00:00<00:00, 13.87it/s]
# val_aupr: {0: np.float64(0.435), 1: np.float64(0.735), 2: np.float64(0.514), 3: np.float64(0.87), 4: np.float64(0.524), 5: np.float64(0.784), 6: np.float64(0.829)}
# 0.67
# val_auroc: {0: np.float64(0.815), 1: np.float64(0.891), 2: np.float64(0.826), 3: np.float64(0.956), 4: np.float64(0.821), 5: np.float64(0.958), 6: np.float64(0.955)}
# 0.889
# val_acc: 0.596
# epoch 10: 100% 53/53 [00:02<00:00, 19.33batch/s, ce_loss=0.0336, lam_loss=0.242]
# val-epoch 10: 100% 10/10 [00:00<00:00, 13.44it/s]
# val_aupr: {0: np.float64(0.437), 1: np.float64(0.737), 2: np.float64(0.514), 3: np.float64(0.868), 4: np.float64(0.537), 5: np.float64(0.805), 6: np.float64(0.825)}
# 0.675
# val_auroc: {0: np.float64(0.815), 1: np.float64(0.891), 2: np.float64(0.831), 3: np.float64(0.951), 4: np.float64(0.827), 5: np.float64(0.958), 6: np.float64(0.955)}
# 0.89
# val_acc: 0.6
# epoch 15: 100% 53/53 [00:02<00:00, 18.99batch/s, ce_loss=0.00355, lam_loss=0.245]
# val-epoch 15: 100% 10/10 [00:00<00:00, 13.75it/s]
# val_aupr: {0: np.float64(0.437), 1: np.float64(0.737), 2: np.float64(0.52), 3: np.float64(0.869), 4: np.float64(0.532), 5: np.float64(0.81), 6: np.float64(0.824)}
# 0.676
# ...
# 0.877
# val_acc: 0.611
# epoch 40: 100% 49/49 [00:02<00:00, 20.62batch/s, loss=0.00199]
# val-epoch 40: 100% 9/9 [00:00<00:00, 13.38it/s]
# val_aupr: {0: np.float64(0.381), 1: np.float64(0.681), 2: np.float64(0.697), 3: np.float64(0.831), 4: np.float64(0.612), 5: np.float64(0.749), 6: np.float64(0.59)}
# 0.649
# val_auroc: {0: np.float64(0.817), 1: np.float64(0.888), 2: np.float64(0.867), 3: np.float64(0.933), 4: np.float64(0.827), 5: np.float64(0.936), 6: np.float64(0.867)}
# 0.876
# val_acc: 0.608
#
# Results:
# {
#   "baseline": {
#     "acc": 0.213,
#     "pr": {
#       "overall": 0.269,
#       "stratified": {
#         "0": 0.191,
#         "1": 0.196,
#         "2": 0.146,
#         "3": 0.253,
#         "4": 0.059,
#         "5": 0.279,
#         "6": 0.756
#       }
#     },
#     "roc": {
#       "overall": 0.609,
#       "stratified": {
#         "0": 0.225,
#         "1": 0.595,
#         "2": 0.642,
#         "3": 0.756,
#         "4": 0.422,
#         "5": 0.739,
#         "6": 0.885
#       }
#     }
#   },
#   "lam0": {
#     "acc": 0.231,
#     "pr": {
#       "overall": 0.288,
#       "stratified": {
#         "0": 0.18,
#         "1": 0.187,
#         "2": 0.134,
#         "3": 0.276,
#         "4": 0.064,
#         "5": 0.353,
#         "6": 0.825
#       }
#     },
#     "roc": {
#       "overall": 0.615,
#       "stratified": {
#         "0": 0.152,
#         "1": 0.569,
#         "2": 0.609,
#         "3": 0.809,
#         "4": 0.464,
#         "5": 0.773,
#         "6": 0.931
#       }
#     }
#   },
#   "lam1": {
#     "acc": 0.225,
#     "pr": {
#       "overall": 0.276,
#       "stratified": {
#         "0": 0.174,
#         "1": 0.201,
#         "2": 0.137,
#         "3": 0.291,
#         "4": 0.058,
#         "5": 0.354,
#         "6": 0.718
#       }
#     },
#     "roc": {
#       "overall": 0.601,
#       "stratified": {
#         "0": 0.117,
#         "1": 0.598,
#         "2": 0.625,
#         "3": 0.789,
#         "4": 0.401,
#         "5": 0.769,
#         "6": 0.905
#       }
#     }
#   },
#   "lam2": {
#     "acc": 0.208,
#     "pr": {
#       "overall": 0.255,
#       "stratified": {
#         "0": 0.17,
#         "1": 0.202,
#         "2": 0.139,
#         "3": 0.224,
#         "4": 0.057,
#         "5": 0.327,
#         "6": 0.669
#       }
#     },
#     "roc": {
#       "overall": 0.591,
#       "stratified": {
#         "0": 0.077,
#         "1": 0.597,
#         "2": 0.615,
#         "3": 0.784,
#         "4": 0.401,
#         "5": 0.786,
#         "6": 0.88
#       }
#     }
#   },
#   "lam3": {
#     "acc": 0.223,
#     "pr": {
#       "overall": 0.274,
#       "stratified": {
#         "0": 0.171,
#         "1": 0.209,
#         "2": 0.12,
#         "3": 0.241,
#         "4": 0.059,
#         "5": 0.354,
#         "6": 0.763
#       }
#     },
#     "roc": {
#       "overall": 0.596,
#       "stratified": {
#         "0": 0.091,
#         "1": 0.614,
#         "2": 0.565,
#         "3": 0.79,
#         "4": 0.412,
#         "5": 0.788,
#         "6": 0.911
#       }
#     }
#   },
#   "clear": {
#     "acc": 0.208,
#     "pr": {
#       "overall": 0.258,
#       "stratified": {
#         "0": 0.197,
#         "1": 0.163,
#         "2": 0.13,
#         "3": 0.204,
#         "4": 0.066,
#         "5": 0.329,
#         "6": 0.717
#       }
#     },
#     "roc": {
#       "overall": 0.592,
#       "stratified": {
#         "0": 0.26,
#         "1": 0.511,
#         "2": 0.581,
#         "3": 0.672,
#         "4": 0.48,
#         "5": 0.759,
#         "6": 0.881
#       }
#     }
#   }
# }
# Complete iteration 9
# Running iteration 10
# Experiment: k=1, seed=152
# {0: {'test': ['art_painting', 'cartoon', 'photo'], 'train': ['sketch']},
#  1: {'test': ['art_painting', 'cartoon', 'sketch'], 'train': ['photo']},
#  2: {'test': ['art_painting', 'cartoon', 'sketch'], 'train': ['photo']},
#  3: {'test': ['art_painting', 'photo', 'sketch'], 'train': ['cartoon']},
#  4: {'test': ['cartoon', 'photo', 'sketch'], 'train': ['art_painting']},
#  5: {'test': ['art_painting', 'cartoon', 'sketch'], 'train': ['photo']},
#  6: {'test': ['art_painting', 'cartoon', 'photo'], 'train': ['sketch']}}
#
# Training baseline:
# epoch 0: 100% 13/13 [00:00<00:00, 13.18batch/s, loss=0.99]
# val-epoch 0: 100% 3/3 [00:00<00:00,  8.14it/s]
# val_aupr: {0: np.float64(0.79), 1: np.float64(0.521), 2: np.float64(0.25), 3: np.float64(0.542), 4: np.float64(0.178), 5: np.float64(0.46), 6: np.float64(0.928)}
# 0.524
# val_auroc: {0: np.float64(0.904), 1: np.float64(0.907), 2: np.float64(0.805), 3: np.float64(0.845), 4: np.float64(0.778), 5: np.float64(0.844), 6: np.float64(0.993)}
# 0.868
# val_acc: 0.087
# epoch 5: 100% 13/13 [00:00<00:00, 15.65batch/s, loss=0.157]
# val-epoch 5: 100% 3/3 [00:00<00:00,  8.57it/s]
# val_aupr: {0: np.float64(0.999), 1: np.float64(0.757), 2: np.float64(0.466), 3: np.float64(0.981), 4: np.float64(0.803), 5: np.float64(0.955), 6: np.float64(0.984)}
# 0.849
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.952), 2: np.float64(0.914), 3: np.float64(0.998), 4: np.float64(0.975), 5: np.float64(0.99), 6: np.float64(0.998)}
# 0.975
# val_acc: 0.83
# epoch 10: 100% 13/13 [00:00<00:00, 15.51batch/s, loss=0.0672]
# val-epoch 10: 100% 3/3 [00:00<00:00,  8.76it/s]
# val_aupr: {0: np.float64(0.999), 1: np.float64(0.751), 2: np.float64(0.495), 3: np.float64(0.987), 4: np.float64(0.785), 5: np.float64(0.965), 6: np.float64(0.993)}
# 0.854
# val_auroc: {0: np.float64(1.0), 1: np.float64(0.936), 2: np.float64(0.921), 3: np.float64(0.999), 4: np.float64(0.969), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.974
# val_acc: 0.844
# epoch 15: 100% 13/13 [00:00<00:00, 15.63batch/s, loss=0.0374]
# val-epoch 15: 100% 3/3 [00:00<00:00,  8.57it/s]
# val_aupr: {0: np.float64(0.999), 1: np.float64(0.769), 2: np.float64(0.561), 3: np.float64(0.99), 4: np.float64(0.78), 5: np.float64(0.966), 6: np.float64(0.992)}
# 0.865
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.949), 2: np.float64(0.922), 3: np.float64(0.999), 4: np.float64(0.972), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.976
# val_acc: 0.848
# epoch 20: 100% 13/13 [00:00<00:00, 16.00batch/s, loss=0.0221]
# val-epoch 20: 100% 3/3 [00:00<00:00,  8.68it/s]
# val_aupr: {0: np.float64(0.999), 1: np.float64(0.763), 2: np.float64(0.543), 3: np.float64(0.987), 4: np.float64(0.777), 5: np.float64(0.966), 6: np.float64(0.99)}
# 0.861
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.947), 2: np.float64(0.924), 3: np.float64(0.999), 4: np.float64(0.971), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.976
# val_acc: 0.844
# epoch 25: 100% 13/13 [00:00<00:00, 15.71batch/s, loss=0.0151]
# val-epoch 25: 100% 3/3 [00:00<00:00,  8.82it/s]
# val_aupr: {0: np.float64(0.999), 1: np.float64(0.769), 2: np.float64(0.571), 3: np.float64(0.988), 4: np.float64(0.788), 5: np.float64(0.969), 6: np.float64(0.99)}
# 0.868
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.952), 2: np.float64(0.925), 3: np.float64(0.999), 4: np.float64(0.973), 5: np.float64(0.993), 6: np.float64(0.999)}
# 0.977
# val_acc: 0.834
# epoch 30: 100% 13/13 [00:00<00:00, 15.97batch/s, loss=0.0117]
# val-epoch 30: 100% 3/3 [00:00<00:00,  8.33it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.775), 2: np.float64(0.566), 3: np.float64(0.984), 4: np.float64(0.79), 5: np.float64(0.965), 6: np.float64(0.99)}
# 0.867
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.953), 2: np.float64(0.925), 3: np.float64(0.998), 4: np.float64(0.973), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.977
# val_acc: 0.841
# epoch 35: 100% 13/13 [00:00<00:00, 15.53batch/s, loss=0.00868]
# val-epoch 35: 100% 3/3 [00:00<00:00,  8.25it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.773), 2: np.float64(0.569), 3: np.float64(0.984), 4: np.float64(0.786), 5: np.float64(0.965), 6: np.float64(0.988)}
# 0.866
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.953), 2: np.float64(0.925), 3: np.float64(0.998), 4: np.float64(0.972), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.977
# val_acc: 0.841
# epoch 40: 100% 13/13 [00:00<00:00, 16.03batch/s, loss=0.00834]
# val-epoch 40: 100% 3/3 [00:00<00:00,  8.74it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.774), 2: np.float64(0.568), 3: np.float64(0.985), 4: np.float64(0.787), 5: np.float64(0.964), 6: np.float64(0.986)}
# 0.866
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.953), 2: np.float64(0.925), 3: np.float64(0.999), 4: np.float64(0.972), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.977
# val_acc: 0.841
#
# Training lam0:
# epoch 0: 100% 13/13 [00:00<00:00, 13.64batch/s, ce_loss=0.773, lam_loss=0.115]
# val-epoch 0: 100% 3/3 [00:00<00:00,  8.19it/s]
# val_aupr: {0: np.float64(0.979), 1: np.float64(0.703), 2: np.float64(0.27), 3: np.float64(0.942), 4: np.float64(0.592), 5: np.float64(0.748), 6: np.float64(0.903)}
# 0.734
# val_auroc: {0: np.float64(0.988), 1: np.float64(0.943), 2: np.float64(0.821), 3: np.float64(0.995), 4: np.float64(0.93), 5: np.float64(0.949), 6: np.float64(0.992)}
# 0.945
# val_acc: 0.644
# epoch 5: 100% 13/13 [00:00<00:00, 14.53batch/s, ce_loss=0.082, lam_loss=0.162]
# val-epoch 5: 100% 3/3 [00:00<00:00,  7.96it/s]
# val_aupr: {0: np.float64(0.997), 1: np.float64(0.734), 2: np.float64(0.494), 3: np.float64(0.963), 4: np.float64(0.821), 5: np.float64(0.955), 6: np.float64(0.968)}
# 0.847
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.961), 2: np.float64(0.905), 3: np.float64(0.993), 4: np.float64(0.98), 5: np.float64(0.991), 6: np.float64(0.997)}
# 0.975
# val_acc: 0.851
# epoch 10: 100% 13/13 [00:00<00:00, 15.13batch/s, ce_loss=0.0111, lam_loss=0.173]
# val-epoch 10: 100% 3/3 [00:00<00:00,  8.40it/s]
# val_aupr: {0: np.float64(0.996), 1: np.float64(0.734), 2: np.float64(0.476), 3: np.float64(0.959), 4: np.float64(0.829), 5: np.float64(0.954), 6: np.float64(0.973)}
# 0.846
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.959), 2: np.float64(0.903), 3: np.float64(0.983), 4: np.float64(0.983), 5: np.float64(0.991), 6: np.float64(0.998)}
# 0.974
# val_acc: 0.844
# epoch 15: 100% 13/13 [00:00<00:00, 15.33batch/s, ce_loss=0.00743, lam_loss=0.197]
# val-epoch 15: 100% 3/3 [00:00<00:00,  8.41it/s]
# val_aupr: {0: np.float64(0.995), 1: np.float64(0.745), 2: np.float64(0.511), 3: np.float64(0.955), 4: np.float64(0.833), 5: np.float64(0.959), 6: np.float64(0.969)}
# 0.852
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.962), 2: np.float64(0.907), 3: np.float64(0.978), 4: np.float64(0.983), 5: np.float64(0.992), 6: np.float64(0.997)}
# 0.974
# val_acc: 0.851
# epoch 20: 100% 13/13 [00:00<00:00, 14.82batch/s, ce_loss=0.00328, lam_loss=0.192]
# val-epoch 20: 100% 3/3 [00:00<00:00,  8.37it/s]
# val_aupr: {0: np.float64(0.996), 1: np.float64(0.746), 2: np.float64(0.506), 3: np.float64(0.958), 4: np.float64(0.835), 5: np.float64(0.961), 6: np.float64(0.971)}
# 0.853
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.962), 2: np.float64(0.908), 3: np.float64(0.98), 4: np.float64(0.983), 5: np.float64(0.992), 6: np.float64(0.997)}
# 0.974
# val_acc: 0.855
# epoch 25: 100% 13/13 [00:00<00:00, 15.38batch/s, ce_loss=0.00239, lam_loss=0.194]
# val-epoch 25: 100% 3/3 [00:00<00:00,  8.29it/s]
# val_aupr: {0: np.float64(0.995), 1: np.float64(0.746), 2: np.float64(0.524), 3: np.float64(0.953), 4: np.float64(0.829), 5: np.float64(0.962), 6: np.float64(0.968)}
# 0.854
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.963), 2: np.float64(0.907), 3: np.float64(0.978), 4: np.float64(0.983), 5: np.float64(0.993), 6: np.float64(0.997)}
# 0.974
# val_acc: 0.862
# epoch 30: 100% 13/13 [00:00<00:00, 15.37batch/s, ce_loss=0.00165, lam_loss=0.178]
# val-epoch 30: 100% 3/3 [00:00<00:00,  8.23it/s]
# val_aupr: {0: np.float64(0.996), 1: np.float64(0.754), 2: np.float64(0.516), 3: np.float64(0.958), 4: np.float64(0.84), 5: np.float64(0.962), 6: np.float64(0.973)}
# 0.857
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.963), 2: np.float64(0.903), 3: np.float64(0.981), 4: np.float64(0.983), 5: np.float64(0.992), 6: np.float64(0.998)}
# 0.974
# val_acc: 0.851
# epoch 35: 100% 13/13 [00:00<00:00, 15.02batch/s, ce_loss=0.00149, lam_loss=0.188]
# val-epoch 35: 100% 3/3 [00:00<00:00,  8.38it/s]
# val_aupr: {0: np.float64(0.996), 1: np.float64(0.75), 2: np.float64(0.512), 3: np.float64(0.958), 4: np.float64(0.837), 5: np.float64(0.962), 6: np.float64(0.97)}
# 0.855
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.961), 2: np.float64(0.907), 3: np.float64(0.979), 4: np.float64(0.983), 5: np.float64(0.993), 6: np.float64(0.997)}
# 0.974
# val_acc: 0.862
# epoch 40: 100% 13/13 [00:00<00:00, 14.91batch/s, ce_loss=0.00095, lam_loss=0.201]
# val-epoch 40: 100% 3/3 [00:00<00:00,  8.19it/s]
# val_aupr: {0: np.float64(0.996), 1: np.float64(0.751), 2: np.float64(0.524), 3: np.float64(0.958), 4: np.float64(0.842), 5: np.float64(0.965), 6: np.float64(0.973)}
# 0.858
# val_auroc: {0: np.float64(0.997), 1: np.float64(0.963), 2: np.float64(0.906), 3: np.float64(0.981), 4: np.float64(0.983), 5: np.float64(0.993), 6: np.float64(0.998)}
# 0.974
# val_acc: 0.858
#
# Training lam1:
# epoch 0: 100% 13/13 [00:00<00:00, 14.65batch/s, ce_loss=0.714, lam_loss=0.124]
# val-epoch 0: 100% 3/3 [00:00<00:00,  8.34it/s]
# val_aupr: {0: np.float64(0.981), 1: np.float64(0.703), 2: np.float64(0.308), 3: np.float64(0.944), 4: np.float64(0.576), 5: np.float64(0.726), 6: np.float64(0.914)}
# 0.736
# val_auroc: {0: np.float64(0.988), 1: np.float64(0.946), 2: np.float64(0.825), 3: np.float64(0.992), 4: np.float64(0.924), 5: np.float64(0.95), 6: np.float64(0.992)}
# 0.945
# val_acc: 0.599
# epoch 5: 100% 13/13 [00:00<00:00, 15.21batch/s, ce_loss=0.0659, lam_loss=0.166]
# val-epoch 5: 100% 3/3 [00:00<00:00,  8.07it/s]
# val_aupr: {0: np.float64(0.997), 1: np.float64(0.79), 2: np.float64(0.493), 3: np.float64(0.976), 4: np.float64(0.83), 5: np.float64(0.96), 6: np.float64(0.985)}
# 0.862
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.963), 2: np.float64(0.913), 3: np.float64(0.997), 4: np.float64(0.975), 5: np.float64(0.991), 6: np.float64(0.998)}
# 0.976
# val_acc: 0.83
# epoch 10: 100% 13/13 [00:00<00:00, 15.06batch/s, ce_loss=0.0128, lam_loss=0.188]
# val-epoch 10: 100% 3/3 [00:00<00:00,  8.20it/s]
# val_aupr: {0: np.float64(0.997), 1: np.float64(0.797), 2: np.float64(0.543), 3: np.float64(0.966), 4: np.float64(0.838), 5: np.float64(0.967), 6: np.float64(0.989)}
# 0.871
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.966), 2: np.float64(0.923), 3: np.float64(0.993), 4: np.float64(0.976), 5: np.float64(0.993), 6: np.float64(0.999)}
# 0.978
# val_acc: 0.862
# epoch 15: 100% 13/13 [00:00<00:00, 14.44batch/s, ce_loss=0.00608, lam_loss=0.19]
# val-epoch 15: 100% 3/3 [00:00<00:00,  7.71it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.797), 2: np.float64(0.549), 3: np.float64(0.968), 4: np.float64(0.837), 5: np.float64(0.968), 6: np.float64(0.988)}
# 0.872
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.965), 2: np.float64(0.925), 3: np.float64(0.994), 4: np.float64(0.976), 5: np.float64(0.993), 6: np.float64(0.999)}
# 0.979
# val_acc: 0.855
# epoch 20: 100% 13/13 [00:00<00:00, 15.25batch/s, ce_loss=0.00283, lam_loss=0.206]
# val-epoch 20: 100% 3/3 [00:00<00:00,  8.02it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.804), 2: np.float64(0.552), 3: np.float64(0.97), 4: np.float64(0.838), 5: np.float64(0.967), 6: np.float64(0.989)}
# 0.874
# val_auroc: {0: np.float64(0.998), 1: np.float64(0.967), 2: np.float64(0.927), 3: np.float64(0.994), 4: np.float64(0.976), 5: np.float64(0.993), 6: np.float64(0.999)}
# 0.979
# val_acc: 0.855
# epoch 25: 100% 13/13 [00:00<00:00, 15.03batch/s, ce_loss=0.00229, lam_loss=0.205]
# val-epoch 25: 100% 3/3 [00:00<00:00,  8.16it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.802), 2: np.float64(0.56), 3: np.float64(0.968), 4: np.float64(0.835), 5: np.float64(0.966), 6: np.float64(0.989)}
# 0.874
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.966), 2: np.float64(0.928), 3: np.float64(0.994), 4: np.float64(0.975), 5: np.float64(0.992), 6: np.float64(0.999)}
# 0.979
# val_acc: 0.851
# epoch 30: 100% 13/13 [00:00<00:00, 15.31batch/s, ce_loss=0.00135, lam_loss=0.202]
# val-epoch 30: 100% 3/3 [00:00<00:00,  8.03it/s]
# val_aupr: {0: np.float64(0.998), 1: np.float64(0.806), 2: np.float64(0.571), 3: np.float64(0.968), 4: np.float64(0.835), 5: np.float64(0.969), 6: np.float64(0.989)}
# 0.877
# val_auroc: {0: np.float64(0.999), 1: np.float64(0.965), 2: np.float64(0.929), 3: np.float64(0.994), 4: np.float64(0.975), 5: np.float64(0.993), 6: np.float64(0.999)}
# 0.979
# val_acc: 0.858
# epoch 35: 100% 13/13 [00:00<00:00, 15.19batch/s, ce_loss=0.00113, lam_loss=0.209]
# val-epoch 35:   0% 0/3 [00:00<?, ?it/s]
