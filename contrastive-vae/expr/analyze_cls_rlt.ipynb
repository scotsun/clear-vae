# %%
import json
import os
import pandas as pd

# %%
K = 3
cnn_acc_list, cnn_roc_list, cnn_pr_list = [], [], []
mlvae_acc_list, mlvae_roc_list, mlvae_pr_list = [], [], []
clearvae_acc_list, clearvae_roc_list, clearvae_pr_list = [], [], []

for file_name in os.listdir("../expr_output/celeba/classification"):
    if file_name.startswith(f"celeba-k{K}") and file_name.endswith(".json"):
        with open(f"../expr_output/celeba/classification/{file_name}", "r") as f:
            data = json.load(f)
            cnn_acc_list.append(data["cnn"]["acc"])
            cnn_pr_list.append(data["cnn"]["pr"]["overall"])
            cnn_roc_list.append(data["cnn"]["roc"]["overall"])

            mlvae_acc_list.append(data["ml-vae + mlp"]["acc"])
            mlvae_pr_list.append(data["ml-vae + mlp"]["pr"]["overall"])
            mlvae_roc_list.append(data["ml-vae + mlp"]["roc"]["overall"])

            clearvae_acc_list.append(data["clear-vae + mlp"]["acc"])
            clearvae_pr_list.append(data["clear-vae + mlp"]["pr"]["overall"])
            clearvae_roc_list.append(data["clear-vae + mlp"]["roc"]["overall"])
df = pd.DataFrame({
    'cnn_acc': cnn_acc_list,
    'mlvae_acc': mlvae_acc_list,
    'clearvae_acc': clearvae_acc_list,
    'cnn_roc': cnn_roc_list,
    'mlvae_roc': mlvae_roc_list,
    'clearvae_roc': clearvae_roc_list,
    'cnn_pr': cnn_pr_list,
    'mlvae_pr': mlvae_pr_list,
    'clearvae_pr': clearvae_pr_list
})
df.describe().iloc[3:, :].loc[["50%", "25%", "75%", "min", "max"],:]
# Out:
#      cnn_acc  mlvae_acc  clearvae_acc  cnn_roc  mlvae_roc  clearvae_roc  \
# 50%  0.59400    0.50800       0.63950  0.89050      0.804        0.9020
# 25%  0.56950    0.44500       0.58800  0.84125      0.785        0.8430
# 75%  0.73125    0.54425       0.72475  0.90350      0.817        0.9135
# min  0.53600    0.35300       0.52200  0.81600      0.690        0.8130
# max  0.77300    0.62700       0.76600  0.93000      0.850        0.9250
#
#       cnn_pr  mlvae_pr  clearvae_pr
# 50%  0.62400   0.51200       0.6130
# 25%  0.52625   0.44925       0.5150
# 75%  0.69425   0.55025       0.7015
# min  0.50200   0.35800       0.5030
# max  0.80300   0.60900       0.7440

# %%
for K in range(1, 4):
    rel_acc_list, rel_roc_list, rel_pr_list = [], [], []

    for file_name in os.listdir("../expr_output/celeba/classification"):
        if file_name.startswith(f"celeba-k{K}") and file_name.endswith(".json"):
            with open(f"../expr_output/celeba/classification/{file_name}", "r") as f:
                data = json.load(f)
                rel_acc_list.append(
                    data["clear-vae + mlp"]["acc"] / data["cnn"]["acc"])
                rel_pr_list.append(
                    data["clear-vae + mlp"]["pr"]["overall"] / data["cnn"]["pr"]["overall"])
                rel_roc_list.append(
                    data["clear-vae + mlp"]["roc"]["overall"] / data["cnn"]["roc"]["overall"])

    df_rel = pd.DataFrame({
        'rel_acc': rel_acc_list,
        'rel_roc': rel_roc_list,
        'rel_pr': rel_pr_list
    })
    print(df_rel.describe().iloc[3:, :].loc[["50%", "25%", "75%", "min", "max"],:].transpose().round(3))
# Out:
#            50%    25%    75%    min    max
# rel_acc  0.904  0.870  0.933  0.831  0.949
# rel_roc  0.959  0.923  0.967  0.889  1.011
# rel_pr   0.884  0.848  0.938  0.817  0.975
#            50%    25%    75%    min    max
# rel_acc  0.992  0.968  1.016  0.924  1.030
# rel_roc  0.995  0.986  1.005  0.964  1.019
# rel_pr   0.989  0.929  1.010  0.911  1.037
#            50%    25%    75%    min    max
# rel_acc  1.006  0.978  1.029  0.970  1.127
# rel_roc  1.003  0.995  1.011  0.986  1.025
# rel_pr   0.990  0.976  1.001  0.927  1.047

# %%
for K in range(1, 4):
    rel_acc_list, rel_roc_list, rel_pr_list = [], [], []

    for file_name in os.listdir("../expr_output/celeba/classification"):
        if file_name.startswith(f"celeba-k{K}") and file_name.endswith(".json"):
            with open(f"../expr_output/celeba/classification/{file_name}", "r") as f:
                data = json.load(f)
                rel_acc_list.append(
                    data["ml-vae + mlp"]["acc"] / data["cnn"]["acc"])
                rel_pr_list.append(
                    data["ml-vae + mlp"]["pr"]["overall"] / data["cnn"]["pr"]["overall"])
                rel_roc_list.append(
                    data["ml-vae + mlp"]["roc"]["overall"] / data["cnn"]["roc"]["overall"])

    df_rel = pd.DataFrame({
        'rel_acc': rel_acc_list,
        'rel_roc': rel_roc_list,
        'rel_pr': rel_pr_list
    })
    print(df_rel.describe().iloc[3:, :].loc[["50%", "25%", "75%", "min", "max"],:].transpose().round(3))
# Out:
#            50%    25%    75%    min    max
# rel_acc  0.715  0.643  0.740  0.538  0.765
# rel_roc  0.818  0.803  0.843  0.754  0.862
# rel_pr   0.694  0.677  0.732  0.565  0.754
#            50%    25%    75%    min    max
# rel_acc  0.679  0.606  0.747  0.517  0.812
# rel_roc  0.840  0.822  0.875  0.745  0.914
# rel_pr   0.697  0.654  0.743  0.589  0.813
#            50%    25%    75%    min    max
# rel_acc  0.754  0.681  0.839  0.653  0.950
# rel_roc  0.907  0.881  0.917  0.839  0.994
# rel_pr   0.810  0.783  0.868  0.620  0.977
